# %%
a="Twinkle, Twinke, Litte Star,";
b= "  How I Wonder what you are!";
c= "       Up above the world so high.";
d="         Like a Diamond in the Sky";
e="Twinkle, Twinke, Litte Star,";
f="   How I wonder what you are";
print (a);
print (b);
print (c);
print (d);
print (e);
print (f);
# Out:
# Twinkle, Twinke, Litte Star,
#   How I Wonder what you are!
#        Up above the world so high.
#          Like a Diamond in the Sky
# Twinkle, Twinke, Litte Star,
#    How I wonder what you are

# %%
import platform
print (platform.version())
# Out:
# #36~18.04.1-Ubuntu SMP Wed Dec 16 23:49:28 UTC 2020

# %%
python ––version
# Out:
#   File "<ipython-input-3-e9e9452c30cc>", line 1
#     python ––version
#                    ^
# SyntaxError: invalid character in identifier

# %%
import sys
print ("Python Version")
print(sys.version)
# Out:
# Python Version
# 3.6.13 | packaged by conda-forge | (default, Sep 23 2021, 07:56:31)
# [GCC 9.4.0]

# %%
import datetime
now = datetime.datetime.now()
print ("Current date and time : ")
print (now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Current date and time :
# 2022-01-01 17:15:27

# %%
fname = input("Input your First Name : ")
lname = input("Input your Last Name : ")
print ("Hello  " + lname + " " + fname)
# Out:
# Input your First Name : Muhammad Ali
# Input your Last Name : Hamza
# Hello  Hamza Muhammad Ali

# %%
from math import pi
r = float(input ("Input the radius of the circle : "))
print ("The area of the circle with radius " + str(r) + " is: " + str(pi * r**2))
# Out:
# Input the radius of the circle : 65
# The area of the circle with radius 65.0 is: 13273.228961416877

# %%
a= int(input("a="))
b= int(input("b="))
sum= a + b
print("The Total Number is=" , sum)
# Out:
# a=45
# b=45
# The Total Number is= 90
